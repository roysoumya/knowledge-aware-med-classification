# %%
import os
os.chdir("drive/My Drive/project")

# %%
# !git clone https://github.com/yao8839836/text_gcn.git
# Out:
# Cloning into 'text_gcn'...
# remote: Enumerating objects: 26801, done.
# remote: Total 26801 (delta 0), reused 0 (delta 0), pack-reused 26801
# Receiving objects: 100% (26801/26801), 861.50 MiB | 12.06 MiB/s, done.
# Resolving deltas: 100% (205/205), done.
# Checking out files: 100% (26397/26397), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls
# Out:
# DATA	  fbprophet  lrp_toolbox  text_gcn
# dl_model  image      ml_models	  Untitled0.ipynb

# %%
# !git clone https://github.com/yao8839836/text_gcn/tree/master/data/ohsumed_single_23
# Out:
# Cloning into 'ohsumed_single_23'...
# fatal: repository 'https://github.com/yao8839836/text_gcn/tree/master/data/ohsumed_single_23/' not found

# %%
# !ls
# Out:
#  Aimed							 ml-1m
#  analytics-zoo-bigdl_0.10.0-spark_2.4.3-0.8.1-dist-all	 project
#  app_developement_udemy					 Recommendation_Engine
# 'Colab Notebooks'					 sample
#  data							 Untitled0.ipynb
# 'Getting started.pdf'					 wide_and_deep.ipynb

# %%
os.chdir("text_gcn/data")

# %%
# !ls
# Out:
# 20ng			 ind.citeseer.x		ind.pubmed.x
# 20ng_doc_vectors_0.txt	 ind.citeseer.y		ind.pubmed.y
# 20ng_doc_vectors_1.txt	 ind.cora.allx		mr
# 20ng_doc_vectors.txt	 ind.cora.ally		mr.txt
# 20ng.txt		 ind.cora.graph		ohsumed_single_23
# aclImdb.txt		 ind.cora.test.index	ohsumed.txt
# ag_news.txt		 ind.cora.tx		R52
# corpus			 ind.cora.ty		R52.txt
# dblp.txt		 ind.cora.x		R8
# dbpedia.txt		 ind.cora.y		R8.txt
# ind.citeseer.allx	 ind.pubmed.allx	rcv1.txt
# ind.citeseer.ally	 ind.pubmed.ally	TREC.txt
# ind.citeseer.graph	 ind.pubmed.graph	WebKB.txt
# ind.citeseer.test.index  ind.pubmed.test.index	wiki.txt
# ind.citeseer.tx		 ind.pubmed.tx
# ind.citeseer.ty		 ind.pubmed.ty

# %%
os.chdir("ohsumed_single_23")

# %%
# !ls training/C01
# Out:
# 0000335  0002382  0002981  0004462  0005168  0005962  0006979  0008106	0009166
# 0000356  0002385  0003118  0004625  0005262  0006095  0007180  0008145	0009284
# 0000358  0002515  0003257  0004628  0005376  0006325  0007401  0008146	0009371
# 0000418  0002555  0003285  0004629  0005378  0006398  0007406  0008201	0009424
# 0000756  0002717  0003718  0004631  0005632  0006498  0007407  0008305	0009509
# 0000777  0002814  0004031  0004632  0005633  0006518  0007539  0008307	0009883
# 0000794  0002821  0004312  0004634  0005638  0006532  0007592  0008323	0009888
# 0000875  0002836  0004336  0004643  0005698  0006549  0007597  0008326	0009890
# 0000876  0002865  0004340  0004659  0005909  0006679  0007675  0008349	0009940
# 0000877  0002878  0004341  0004662  0005918  0006739  0007849  0008481	0009948
# 0000880  0002887  0004342  0004663  0005923  0006855  0007850  0008843
# 0000882  0002889  0004344  0004672  0005932  0006864  0007853  0009120
# ...

# %%
list1 = ['C01/','C02/','C03/','C04/','C05/','C06/','C07/','C08/','C09/','C10/','C11/','C12/','C13/','C14/','C15/','C16/','C17/','C18/','C19/','C20/','C21/','C22/','C23/']

# %%
path = 'training/'

# %%
# !ls training/C02
# Out:
# 0002879  0004121  0004621  0004655  0005940  0006165  0008246  0009022	0009900
# 0002972  0004300  0004622  0005272  0005948  0006534  0008416  0009210
# 0004048  0004309  0004653  0005366  0006135  0008144  0008451  0009402

# %%
len1=0
import pandas as pd

# %%
mylist=[]
for each in list1:
  newpath=path+each
  len1=len1+1
  
  for filename in os.listdir(newpath):
    ff=newpath+filename
    file1=open(ff)
    line= file1.read()
    dict1={'body':line,'lebel':len1}
    mylist.append(dict1)
df=pd.DataFrame(mylist)

# %%
df

# %%
df.to_csv("/content/drive/My Drive/project/DATA/ohsumed_data/train.tsv")

# %%
# !ls
# Out:
# test  training

# %%
# !pwd
# Out:
# /content/drive/My Drive/project/text_gcn/data/ohsumed_single_23

# %%
path = 'test/'

# %%
mylist1=[]
len1=0
for each in list1:
  newpath=path+each
  len1=len1+1
  
  for filename in os.listdir(newpath):
    ff=newpath+filename
    file1=open(ff)
    line= file1.read()
    dict1={'body':line,'lebel':len1}
    mylist1.append(dict1)
df1=pd.DataFrame(mylist1)

# %%
df1
# Out:
#                                                    body  lebel
# 0     Infection in total joint replacement.\n Althou...      1
# 1     Analysis of the immune response to lipopolysac...      1
# 2     Platelet activating factor (PAF) and tumor nec...      1
# 3     The direct costs of universal precautions in a...      1
# 4     Epidemiologic, clinical, and laboratory findin...      1
# ...                                                 ...    ...
# 4038  Traditional versus laparoscopic cholecystectom...     23
# 4039  The European experience with laparoscopic chol...     23
# 4040  Complications of laparoscopic cholecystectomy....     23
# 4041  Interruption of professional and home activity...     23
# 4042  Enhanced mobilization of intracellular Ca2+ in...     23
#
# [4043 rows x 2 columns]

# %%
df1.to_csv("/content/drive/My Drive/project/DATA/ohsumed_data/test.tsv")
